# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\STUDY\PYTHON\big data practice\5. London Housing Data.csv")

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 635.2+ KB

# %%
data.shape
# Out:
# (13549, 6)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=13549, step=1)

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
data['date'].value_counts()
# Out:
# 4/1/1998    47
# 2/1/1996    47
# 4/1/2012    45
# 3/1/2012    45
# 2/1/2012    45
#             ..
# 6/1/2003    45
# 5/1/2003    45
# 4/1/2003    45
# 3/1/2003    45
# 1/1/2020    45
# Name: date, Length: 301, dtype: int64

# %%
data['date'].unique()
# Out:
# array(['1/1/1995', '2/1/1995', '3/1/1995', '4/1/1995', '5/1/1995',
#        '6/1/1995', '7/1/1995', '8/1/1995', '9/1/1995', '10/1/1995',
#        '11/1/1995', '12/1/1995', '1/1/1996', '2/1/1996', '3/1/1996',
#        '4/1/1996', '5/1/1996', '6/1/1996', '7/1/1996', '8/1/1996',
#        '9/1/1996', '10/1/1996', '11/1/1996', '12/1/1996', '1/1/1997',
#        '2/1/1997', '3/1/1997', '4/1/1997', '5/1/1997', '6/1/1997',
#        '7/1/1997', '8/1/1997', '9/1/1997', '10/1/1997', '11/1/1997',
#        '12/1/1997', '1/1/1998', '2/1/1998', '3/1/1998', '4/1/1998',
#        '5/1/1998', '6/1/1998', '7/1/1998', '8/1/1998', '9/1/1998',
#        '10/1/1998', '11/1/1998', '12/1/1998', '1/1/1999', '2/1/1999',
#        '3/1/1999', '4/1/1999', '5/1/1999', '6/1/1999', '7/1/1999',
#        '8/1/1999', '9/1/1999', '10/1/1999', '11/1/1999', '12/1/1999',
#        '1/1/2000', '2/1/2000', '3/1/2000', '4/1/2000', '5/1/2000',
#        '6/1/2000', '7/1/2000', '8/1/2000', '9/1/2000', '10/1/2000',
# ...

# %%
data['area'].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
data['code'].unique()
# Out:
# array(['E09000001', 'E09000002', 'E09000003', 'E09000004', 'E09000005',
#        'E09000006', 'E09000007', 'E09000008', 'E09000009', 'E09000010',
#        'E09000030', 'E09000011', 'E09000012', 'E12000008', 'E09000013',
#        'E09000014', 'E09000015', 'E09000016', 'E09000017', 'E09000018',
#        'E09000019', 'E09000020', 'E09000021', 'E09000022', 'E09000023',
#        'E09000024', 'E09000025', 'E09000026', 'E09000027', 'E09000028',
#        'E09000029', 'E09000031', 'E09000032', 'E09000033', 'E13000001',
#        'E13000002', 'E12000001', 'E12000002', 'E12000003', 'E12000004',
#        'E12000005', 'E12000006', 'E12000007', 'E12000009', 'E92000001'],
#       dtype=object)

# %%
data.nunique()
# Out:
# date               301
# area                45
# average_price    13343
# code                45
# houses_sold       3946
# no_of_crimes      2669
# dtype: int64

# %%
data['code'].nunique()
# Out:
# 45

# %%
data['no_of_crimes'].nunique()
# Out:
# 2669

# %%
data['area'].value_counts()
# Out:
# hackney                   302
# south east                302
# enfield                   302
# tower hamlets             302
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# westminster               301
# inner london              301
# outer london              301
# city of london            301
# merton                    301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# newham                    301
# kingston upon thames      301
# lewisham                  301
# lambeth                   301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# ...

# %%
data["area"].value_counts()
# Out:
# hackney                   302
# south east                302
# enfield                   302
# tower hamlets             302
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# westminster               301
# inner london              301
# outer london              301
# city of london            301
# merton                    301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# newham                    301
# kingston upon thames      301
# lewisham                  301
# lambeth                   301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# ...

# %%
data.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
data.columns
print(data[['date','area','code']])
# Out:
#             date            area       code
# 0       1/1/1995  city of london  E09000001
# 1       2/1/1995  city of london  E09000001
# 2       3/1/1995  city of london  E09000001
# 3       4/1/1995  city of london  E09000001
# 4       5/1/1995  city of london  E09000001
# ...          ...             ...        ...
# 13544   9/1/2019         england  E92000001
# 13545  10/1/2019         england  E92000001
# 13546  11/1/2019         england  E92000001
# 13547  12/1/2019         england  E92000001
# 13548   1/1/2020         england  E92000001
#
# [13549 rows x 3 columns]

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.area.unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
data['area'].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
data.nunique()
# Out:
# date               301
# area                45
# average_price    13343
# code                45
# houses_sold       3946
# no_of_crimes      2669
# dtype: int64

# %%
data[data['area']=='bromley']
# Out:
#            date     area  average_price       code  houses_sold  no_of_crimes
# 1505   1/1/1995  bromley          81671  E09000006        323.0           NaN
# 1506   2/1/1995  bromley          81658  E09000006        326.0           NaN
# 1507   3/1/1995  bromley          81449  E09000006        449.0           NaN
# 1508   4/1/1995  bromley          81124  E09000006        362.0           NaN
# 1509   5/1/1995  bromley          81543  E09000006        428.0           NaN
# ...         ...      ...            ...        ...          ...           ...
# 1801   9/1/2019  bromley         440620  E09000006        353.0        2114.0
# 1802  10/1/2019  bromley         439782  E09000006        417.0        2215.0
# 1803  11/1/2019  bromley         438792  E09000006        374.0        2282.0
# 1804  12/1/2019  bromley         443391  E09000006          NaN        2087.0
# 1805   1/1/2020  bromley         436757  E09000006          NaN        2138.0
#
# [301 rows x 6 columns]

# %%
#data.groupby('area').getgroup('area')

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
data.notnull().sum()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data.rename(columns={'code':'detail code'})
# Out:
#             date            area  average_price detail code  houses_sold  \
# 0       1/1/1995  city of london          91449   E09000001         17.0
# 1       2/1/1995  city of london          82203   E09000001          7.0
# 2       3/1/1995  city of london          79121   E09000001         14.0
# 3       4/1/1995  city of london          77101   E09000001          7.0
# 4       5/1/1995  city of london          84409   E09000001         10.0
# ...          ...             ...            ...         ...          ...
# 13544   9/1/2019         england         249942   E92000001      64605.0
# 13545  10/1/2019         england         249376   E92000001      68677.0
# 13546  11/1/2019         england         248515   E92000001      67814.0
# 13547  12/1/2019         england         250410   E92000001          NaN
# 13548   1/1/2020         england         247355   E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data.rename(columns={'code':'detail codes'},inplace=True)

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0       1/1/1995  city of london          91449    E09000001         17.0
# 1       2/1/1995  city of london          82203    E09000001          7.0
# 2       3/1/1995  city of london          79121    E09000001         14.0
# 3       4/1/1995  city of london          77101    E09000001          7.0
# 4       5/1/1995  city of london          84409    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544   9/1/2019         england         249942    E92000001      64605.0
# 13545  10/1/2019         england         249376    E92000001      68677.0
# 13546  11/1/2019         england         248515    E92000001      67814.0
# 13547  12/1/2019         england         250410    E92000001          NaN
# 13548   1/1/2020         england         247355    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data['average_price']= data['average_price'].apply(lambda x:x+2)

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0       1/1/1995  city of london          91451    E09000001         17.0
# 1       2/1/1995  city of london          82205    E09000001          7.0
# 2       3/1/1995  city of london          79123    E09000001         14.0
# 3       4/1/1995  city of london          77103    E09000001          7.0
# 4       5/1/1995  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544   9/1/2019         england         249944    E92000001      64605.0
# 13545  10/1/2019         england         249378    E92000001      68677.0
# 13546  11/1/2019         england         248517    E92000001      67814.0
# 13547  12/1/2019         england         250412    E92000001          NaN
# 13548   1/1/2020         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0       1/1/1995  city of london          91451    E09000001         17.0
# 1       2/1/1995  city of london          82205    E09000001          7.0
# 2       3/1/1995  city of london          79123    E09000001         14.0
# 3       4/1/1995  city of london          77103    E09000001          7.0
# 4       5/1/1995  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544   9/1/2019         england         249944    E92000001      64605.0
# 13545  10/1/2019         england         249378    E92000001      68677.0
# 13546  11/1/2019         england         248517    E92000001      67814.0
# 13547  12/1/2019         england         250412    E92000001          NaN
# 13548   1/1/2020         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0       1/1/1995  city of london          91451    E09000001         17.0
# 1       2/1/1995  city of london          82205    E09000001          7.0
# 2       3/1/1995  city of london          79123    E09000001         14.0
# 3       4/1/1995  city of london          77103    E09000001          7.0
# 4       5/1/1995  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544   9/1/2019         england         249944    E92000001      64605.0
# 13545  10/1/2019         england         249378    E92000001      68677.0
# 13546  11/1/2019         england         248517    E92000001      67814.0
# 13547  12/1/2019         england         250412    E92000001          NaN
# 13548   1/1/2020         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0       1/1/1995  city of london          91451    E09000001         17.0
# 1       2/1/1995  city of london          82205    E09000001          7.0
# 2       3/1/1995  city of london          79123    E09000001         14.0
# 3       4/1/1995  city of london          77103    E09000001          7.0
# 4       5/1/1995  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544   9/1/2019         england         249944    E92000001      64605.0
# 13545  10/1/2019         england         249378    E92000001      68677.0
# 13546  11/1/2019         england         248517    E92000001      67814.0
# 13547  12/1/2019         england         250412    E92000001          NaN
# 13548   1/1/2020         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# detail codes      object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data['date']=pd.to_datetime(data.date)

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# detail codes             object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data['year']=data.date.dt.year

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# ...

# %%
data['month']=data.date.dt.year

# %%
#Remove the columns 'year' and 'month' from the dataframe.

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes  year  month
# 0               NaN  1995   1995
# ...

# %%
#data.drop(columns=['year', 'month'])

# %%
data
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes  year  month
# 0               NaN  1995   1995
# ...

# %%
data.drop(['year','month'],axis=1)
# Out:
#             date            area  average_price detail codes  houses_sold  \
# 0     1995-01-01  city of london          91451    E09000001         17.0
# 1     1995-02-01  city of london          82205    E09000001          7.0
# 2     1995-03-01  city of london          79123    E09000001         14.0
# 3     1995-04-01  city of london          77103    E09000001          7.0
# 4     1995-05-01  city of london          84411    E09000001         10.0
# ...          ...             ...            ...          ...          ...
# 13544 2019-09-01         england         249944    E92000001      64605.0
# 13545 2019-10-01         england         249378    E92000001      68677.0
# 13546 2019-11-01         england         248517    E92000001      67814.0
# 13547 2019-12-01         england         250412    E92000001          NaN
# 13548 2020-01-01         england         247357    E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# ...

# %%
data.head(5)
# Out:
#         date            area  average_price detail codes  houses_sold  \
# 0 1995-01-01  city of london          91451    E09000001         17.0
# 1 1995-02-01  city of london          82205    E09000001          7.0
# 2 1995-03-01  city of london          79123    E09000001         14.0
# 3 1995-04-01  city of london          77103    E09000001          7.0
# 4 1995-05-01  city of london          84411    E09000001         10.0
#
#    no_of_crimes  year  month
# 0           NaN  1995   1995
# 1           NaN  1995   1995
# 2           NaN  1995   1995
# 3           NaN  1995   1995
# 4           NaN  1995   1995

# %%
#Add a new column ''month'' as 2nd column in the dataframe, which contains month only.

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# detail codes             object
# houses_sold             float64
# no_of_crimes            float64
# year                      int64
# month                     int64
# dtype: object

# %%
#Show all the records where 'No. of Crimes' is 0. And, how many such records are there ?

# %%
data.head(2)
# Out:
#         date            area  average_price detail codes  houses_sold  \
# 0 1995-01-01  city of london          91451    E09000001         17.0
# 1 1995-02-01  city of london          82205    E09000001          7.0
#
#    no_of_crimes  year  month
# 0           NaN  1995   1995
# 1           NaN  1995   1995

# %%
data.no_of_crimes.unique()
# Out:
# array([      nan, 0.000e+00, 7.000e+00, ..., 6.843e+03, 7.461e+03,
#        6.405e+03])

# %%
data[data['no_of_crimes']==0]
# Out:
#           date            area  average_price detail codes  houses_sold  \
# 72  2001-01-01  city of london         284264    E09000001         24.0
# 73  2001-02-01  city of london         198139    E09000001         37.0
# 74  2001-03-01  city of london         189035    E09000001         44.0
# 75  2001-04-01  city of london         205496    E09000001         38.0
# 76  2001-05-01  city of london         223461    E09000001         30.0
# ..         ...             ...            ...          ...          ...
# 178 2009-11-01  city of london         397911    E09000001         11.0
# 179 2009-12-01  city of london         411957    E09000001         16.0
# 180 2010-01-01  city of london         464438    E09000001         20.0
# 181 2010-02-01  city of london         490527    E09000001          9.0
# 182 2010-03-01  city of london         498243    E09000001         15.0
#
#      no_of_crimes  year  month
# 72            0.0  2001   2001
# 73            0.0  2001   2001
# ...
